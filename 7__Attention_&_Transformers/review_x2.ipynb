# %%
class Transformer:
    def call(self):
        enc_out =encoder(x)
        dec_out = decoder(x)

# %%
class Encoder:
    def __init__(self):
        pass
    def call(self):
        attn = self.attn(x,x,x)
        x = self.norm1(attn)

        ffn = self.ffn(x)
        enc_out = self.norm2(ffn)

        return enc_out

# %%
class Decoder:
    def __init__(self):
        pass
    def call(self):
        attn = self.self_mha(x, enc_out,enc_out )
        x = self.norm1(attn)

        attn = self.cross_mha(enc_out)
        x = self.norm2()

        ffn = self.ffn()
        dec_out = self.norm3()
        return output
