# %%
def build_generator(latent_dim, output):
    input = tf.keras.Input(input_shape)
    x = tf.keras.layers.Dense()()
    x  = tf.keras.layers.Dense()()

    return tf.keras.Model(latent_dim, x)

# %%
def build_discriminator(input, output):
    input = tf.keras.Input(input_shape)
    x = tf.keras.layers.Dense(128, activation='relu')(input)
    x = tf.keras.layers.Dense(1, activation = 'sigmoid')(x)
    
    return tf.keras.Model(input, x)

# %%
bce = tf.keras.losses.BinaryCrossentropy()

generator_loss = bce(tf.ones_like(generated_output), generated_output)

discriminator_loss
